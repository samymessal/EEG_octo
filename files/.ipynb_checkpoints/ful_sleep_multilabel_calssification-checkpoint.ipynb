# %% [markdown]
# # Sleep Spindle Study
#
# ## Building Model
#
# In this notebook, we build a model to detect the presence of sleep spindles in the entire EEG recording.

# %% [markdown]
# ## Imports
#
# We will import the necessary libraries that are needed for processing the data, building the model, and evaluating its performance.

# %%
import mne
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
from keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold
import json
import utils
import feature_extraction
import data_preparation
from memory_profiler import profile
import preprocess
import keras
import tensorflow as tf
from tensorflow.keras import backend as K
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.callbacks import Callback
import json
from tensorflow.keras.metrics import Metric
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, LSTM, Dense, BatchNormalization, Flatten
import tensorflow.keras.layers
from tensorflow.keras.models import Sequential
# Out:
# 2023-12-30 15:14:37.047760: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-30 15:14:37.092911: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-30 15:14:37.092959: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-30 15:14:37.093863: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-30 15:14:37.100125: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-30 15:14:37.100745: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-30 15:14:38.082027: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Download data
#
# Using the `processed_data` function from the previous step to download our concatenated raw with its correspondent preprocessing and features.

# %%
X, labels = data_preparation.processed_data(["../dataset/train_S002_night1_hackathon_raw.mat",
                                            "../dataset/train_S003_night5_hackathon_raw.mat"
                                            ],
                                            ["../dataset/train_S002_labeled.csv",
                                            "../dataset/train_S003_labeled.csv"
                                            ],
                                            labels=["K0", "K1"],
                                            fmin=8,
                                            fmax=16,
                                            include_entire_recording=True)
# Out:
# Creating RawArray with float64 data, n_channels=1, n_times=4965399
#     Range : 0 ... 4965398 =      0.000 ... 19861.592 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Used Annotations descriptions: ['0_0', '0_1', '1_0']
# Not setting metadata
# 1191 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 1191 events and 626 original time points ...
# 0 bad epochs dropped
# epcohs.get_data().shape: (1191, 1, 626)
# raw_data.shape: (1, 4965399)
# len(labels_df.index): 1191
# Using data from preloaded Raw for 1191 events and 626 original time points ...
# Creating RawArray with float64 data, n_channels=1, n_times=5772730
#     Range : 0 ... 5772729 =      0.000 ... 23090.916 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Used Annotations descriptions: ['0_0', '0_1', '1_0']
# Not setting metadata
# 1050 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 1050 events and 626 original time points ...
# 0 bad epochs dropped
# epcohs.get_data().shape: (1050, 1, 626)
# raw_data.shape: (1, 5772730)
# len(labels_df.index): 1050
# Using data from preloaded Raw for 1050 events and 626 original time points ...
# Using data from preloaded Raw for 1191 events and 626 original time points ...
# Using data from preloaded Raw for 1050 events and 626 original time points ...
# Not setting metadata
# 2241 matching events found
# Applying baseline correction (mode: mean)

# %% [markdown]
# #### Model
#
# The chosen model is an LSTM, since we are dealing with timeframes, LSTM are known to deal well with time depending samples. A k-cross validation is implemented, partitioning the data into 5 parts and alterning between the 4 parts for training and the 1 for testing.

# %%
class F1Score(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision()
        self.recall = tf.keras.metrics.Recall()
        self.f1_score = self.add_weight(name='f1', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)
        p = self.precision.result()
        r = self.recall.result()
        self.f1_score.assign(2 * ((p * r) / (p + r + tf.keras.backend.epsilon())))

    def result(self):
        return self.f1_score

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()
        self.f1_score.assign(0)

print("X.shape:", X.shape)
print("labels.shape:", labels.shape)
print("shape before reshaping:", X.shape)
X = X.transpose((0, 2, 1))
print("shape after reshaping:", X.shape)
# Out:
# X.shape: (2241, 1, 626)
# labels.shape: (2241, 2)
# shape before reshaping: (2241, 1, 626)
# shape after reshaping: (2241, 626, 1)

# %%
def create_model():
    input_layer = keras.Input(shape=(X.shape[1], X.shape[2]))

    x = Conv1D(
        filters=32, kernel_size=3, strides=1, activation="relu", padding="same"
    )(input_layer)
    x = BatchNormalization()(x)

    x = Conv1D(
        filters=64, kernel_size=3, strides=1, activation="relu", padding="same"
    )(x)
    x = BatchNormalization()(x)

    x = Conv1D(
        filters=128, kernel_size=5, strides=1, activation="relu", padding="same"
    )(x)
    x = BatchNormalization()(x)

    # Now you can flatten the output if you haven't applied global pooling before
    x = Flatten()(x)

    x = Dense(
        2048, activation="relu"
    )(x)
    x = Dropout(0.2)(x)

    x = Dense(
        1024, activation="relu"
    )(x)
    x = Dropout(0.2)(x)
    x = Dense(
        128, activation="relu"
    )(x)
    output_layer = Dense(labels.shape[1], activation="sigmoid")(x)

    return keras.Model(inputs=input_layer, outputs=output_layer)

# %%
kfold = KFold(n_splits=3, shuffle=True)
for fold_no, (train, test) in enumerate(kfold.split(X, labels)):
    print("train indices:", train.shape)
    print("test indices:", test.shape)
    # Define the model architecture
    model = create_model()
    
    # Compile the model
    model.compile(
        optimizer=keras.optimizers.Adam(),
        loss="binary_crossentropy",
        metrics=[
            'accuracy',
            tf.keras.metrics.Precision(),
            tf.keras.metrics.Recall(),
            F1Score(),
        ]
    )
    
    # Train the model
    history = model.fit(
        X[train],
        labels[train],
        epochs=30,
        validation_data=(X[test], labels[test]),
    )


    training_f1_scores = history.history['f1_score']
    validation_f1_scores = history.history['val_f1_score']

    plt.plot(training_f1_scores, label='Training F1 Score')
    plt.plot(validation_f1_scores, label='Validation F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()
    plt.show()
# Out:
# train indices: (1494,)
# test indices: (747,)
# Epoch 1/30
# 47/47 [==============================] - 84s 2s/step - loss: 41.6175 - accuracy: 0.4980 - precision_2: 0.1238 - recall_2: 0.4856 - f1_score: 0.1973 - val_loss: 15.8279 - val_accuracy: 0.7229 - val_precision_2: 0.1446 - val_recall_2: 0.4821 - val_f1_score: 0.2225
# Epoch 2/30
# 47/47 [==============================] - 83s 2s/step - loss: 9.9430 - accuracy: 0.6084 - precision_2: 0.1406 - recall_2: 0.5512 - f1_score: 0.2240 - val_loss: 7.2078 - val_accuracy: 0.3708 - val_precision_2: 0.1687 - val_recall_2: 0.5625 - val_f1_score: 0.2595
# Epoch 3/30
# 47/47 [==============================] - 82s 2s/step - loss: 5.8011 - accuracy: 0.5221 - precision_2: 0.1586 - recall_2: 0.6220 - f1_score: 0.2528 - val_loss: 4.8282 - val_accuracy: 0.2262 - val_precision_2: 0.1981 - val_recall_2: 0.6607 - val_f1_score: 0.3048
# Epoch 4/30
# 47/47 [==============================] - 80s 2s/step - loss: 4.0015 - accuracy: 0.4665 - precision_2: 0.1486 - recall_2: 0.5827 - f1_score: 0.2368 - val_loss: 3.4500 - val_accuracy: 0.6814 - val_precision_2: 0.1539 - val_recall_2: 0.5134 - val_f1_score: 0.2369
# Epoch 5/30
# 47/47 [==============================] - 80s 2s/step - loss: 2.9033 - accuracy: 0.5602 - precision_2: 0.1647 - recall_2: 0.6457 - f1_score: 0.2624 - val_loss: 2.5966 - val_accuracy: 0.2503 - val_precision_2: 0.1888 - val_recall_2: 0.6295 - val_f1_score: 0.2904
# Epoch 6/30
# 47/47 [==============================] - 82s 2s/step - loss: 2.2220 - accuracy: 0.4451 - precision_2: 0.1553 - recall_2: 0.6089 - f1_score: 0.2475 - val_loss: 1.9624 - val_accuracy: 0.5542 - val_precision_2: 0.1794 - val_recall_2: 0.5982 - val_f1_score: 0.2760
# Epoch 7/30
# 47/47 [==============================] - 81s 2s/step - loss: 1.7082 - accuracy: 0.4813 - precision_2: 0.1600 - recall_2: 0.6273 - f1_score: 0.2549 - val_loss: 1.5759 - val_accuracy: 0.5127 - val_precision_2: 0.1914 - val_recall_2: 0.6384 - val_f1_score: 0.2945
# Epoch 8/30
# 47/47 [==============================] - 80s 2s/step - loss: 1.4243 - accuracy: 0.5315 - precision_2: 0.1499 - recall_2: 0.5879 - f1_score: 0.2389 - val_loss: 1.3567 - val_accuracy: 0.4096 - val_precision_2: 0.1995 - val_recall_2: 0.6652 - val_f1_score: 0.3069
# Epoch 9/30
# 47/47 [==============================] - 81s 2s/step - loss: 1.1904 - accuracy: 0.4505 - precision_2: 0.1613 - recall_2: 0.6325 - f1_score: 0.2571 - val_loss: 1.1560 - val_accuracy: 0.2035 - val_precision_2: 0.1928 - val_recall_2: 0.6429 - val_f1_score: 0.2966
# Epoch 10/30
# 47/47 [==============================] - 82s 2s/step - loss: 1.1162 - accuracy: 0.5147 - precision_2: 0.1627 - recall_2: 0.6378 - f1_score: 0.2592 - val_loss: 1.0953 - val_accuracy: 0.6359 - val_precision_2: 0.1861 - val_recall_2: 0.6205 - val_f1_score: 0.2863
# Epoch 11/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.9834 - accuracy: 0.4993 - precision_2: 0.1566 - recall_2: 0.6142 - f1_score: 0.2496 - val_loss: 0.9462 - val_accuracy: 0.4538 - val_precision_2: 0.1928 - val_recall_2: 0.6429 - val_f1_score: 0.2966
# Epoch 12/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.8916 - accuracy: 0.5375 - precision_2: 0.1560 - recall_2: 0.6115 - f1_score: 0.2485 - val_loss: 0.8738 - val_accuracy: 0.4766 - val_precision_2: 0.1995 - val_recall_2: 0.6652 - val_f1_score: 0.3069
# Epoch 13/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.8217 - accuracy: 0.5047 - precision_2: 0.1640 - recall_2: 0.6430 - f1_score: 0.2613 - val_loss: 0.8355 - val_accuracy: 0.6613 - val_precision_2: 0.1780 - val_recall_2: 0.5938 - val_f1_score: 0.2739
# Epoch 14/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.7771 - accuracy: 0.4665 - precision_2: 0.1519 - recall_2: 0.5958 - f1_score: 0.2421 - val_loss: 0.7848 - val_accuracy: 0.2035 - val_precision_2: 0.1901 - val_recall_2: 0.6339 - val_f1_score: 0.2925
# Epoch 15/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.7648 - accuracy: 0.4967 - precision_2: 0.1573 - recall_2: 0.6168 - f1_score: 0.2507 - val_loss: 0.7775 - val_accuracy: 0.6332 - val_precision_2: 0.1673 - val_recall_2: 0.5580 - val_f1_score: 0.2575
# Epoch 16/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.7002 - accuracy: 0.5027 - precision_2: 0.1580 - recall_2: 0.6194 - f1_score: 0.2517 - val_loss: 0.7401 - val_accuracy: 0.6238 - val_precision_2: 0.1660 - val_recall_2: 0.5536 - val_f1_score: 0.2554
# Epoch 17/30
# 47/47 [==============================] - 82s 2s/step - loss: 0.6901 - accuracy: 0.4645 - precision_2: 0.1580 - recall_2: 0.6194 - f1_score: 0.2517 - val_loss: 0.7062 - val_accuracy: 0.2021 - val_precision_2: 0.1928 - val_recall_2: 0.6429 - val_f1_score: 0.2966
# Epoch 18/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.6501 - accuracy: 0.5736 - precision_2: 0.1533 - recall_2: 0.6010 - f1_score: 0.2443 - val_loss: 0.7278 - val_accuracy: 0.5609 - val_precision_2: 0.1821 - val_recall_2: 0.6071 - val_f1_score: 0.2801
# Epoch 19/30
# 47/47 [==============================] - 82s 2s/step - loss: 0.6403 - accuracy: 0.5964 - precision_2: 0.1600 - recall_2: 0.6273 - f1_score: 0.2549 - val_loss: 0.6851 - val_accuracy: 0.6908 - val_precision_2: 0.2008 - val_recall_2: 0.6696 - val_f1_score: 0.3090
# Epoch 20/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.6387 - accuracy: 0.6352 - precision_2: 0.1627 - recall_2: 0.6378 - f1_score: 0.2592 - val_loss: 0.6490 - val_accuracy: 0.4431 - val_precision_2: 0.2035 - val_recall_2: 0.6786 - val_f1_score: 0.3131
# Epoch 21/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.6291 - accuracy: 0.5589 - precision_2: 0.1593 - recall_2: 0.6247 - f1_score: 0.2539 - val_loss: 0.6453 - val_accuracy: 0.4685 - val_precision_2: 0.2021 - val_recall_2: 0.6741 - val_f1_score: 0.3110
# Epoch 22/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.5793 - accuracy: 0.4705 - precision_2: 0.1620 - recall_2: 0.6352 - f1_score: 0.2581 - val_loss: 0.6060 - val_accuracy: 0.1928 - val_precision_2: 0.1928 - val_recall_2: 0.6429 - val_f1_score: 0.2966
# Epoch 23/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.5862 - accuracy: 0.4391 - precision_2: 0.1586 - recall_2: 0.6220 - f1_score: 0.2528 - val_loss: 0.6024 - val_accuracy: 0.2905 - val_precision_2: 0.2008 - val_recall_2: 0.6696 - val_f1_score: 0.3090
# Epoch 24/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.5943 - accuracy: 0.5408 - precision_2: 0.1627 - recall_2: 0.6378 - f1_score: 0.2592 - val_loss: 0.6672 - val_accuracy: 0.6345 - val_precision_2: 0.1794 - val_recall_2: 0.5982 - val_f1_score: 0.2760
# Epoch 25/30
# 47/47 [==============================] - 81s 2s/step - loss: 0.6703 - accuracy: 0.6131 - precision_2: 0.1580 - recall_2: 0.6194 - f1_score: 0.2517 - val_loss: 0.6440 - val_accuracy: 0.6814 - val_precision_2: 0.1928 - val_recall_2: 0.6429 - val_f1_score: 0.2966
# Epoch 26/30
# 47/47 [==============================] - 81s 2s/step - loss: 0.5866 - accuracy: 0.5515 - precision_2: 0.1640 - recall_2: 0.6430 - f1_score: 0.2613 - val_loss: 0.6003 - val_accuracy: 0.4833 - val_precision_2: 0.2008 - val_recall_2: 0.6696 - val_f1_score: 0.3090
# Epoch 27/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.5662 - accuracy: 0.5522 - precision_2: 0.1640 - recall_2: 0.6430 - f1_score: 0.2613 - val_loss: 0.6381 - val_accuracy: 0.7296 - val_precision_2: 0.1861 - val_recall_2: 0.6205 - val_f1_score: 0.2863
# Epoch 28/30
# 47/47 [==============================] - 80s 2s/step - loss: 0.5776 - accuracy: 0.5810 - precision_2: 0.1633 - recall_2: 0.6404 - f1_score: 0.2603 - val_loss: 0.6515 - val_accuracy: 0.6479 - val_precision_2: 0.1794 - val_recall_2: 0.5982 - val_f1_score: 0.2760
# Epoch 29/30
# 47/47 [==============================] - 87s 2s/step - loss: 0.5732 - accuracy: 0.5736 - precision_2: 0.1660 - recall_2: 0.6509 - f1_score: 0.2645 - val_loss: 0.5842 - val_accuracy: 0.5904 - val_precision_2: 0.2021 - val_recall_2: 0.6741 - val_f1_score: 0.3110
# Epoch 30/30
# 47/47 [==============================] - 87s 2s/step - loss: 0.5665 - accuracy: 0.5703 - precision_2: 0.1633 - recall_2: 0.6404 - f1_score: 0.2603 - val_loss: 0.5877 - val_accuracy: 0.6881 - val_precision_2: 0.1794 - val_recall_2: 0.5982 - val_f1_score: 0.2760
# train indices: (1494,)
# test indices: (747,)
# Epoch 1/30
# 47/47 [==============================] - 94s 2s/step - loss: 44.0600 - accuracy: 0.4190 - precision_4: 0.1560 - recall_4: 0.5669 - f1_score: 0.2446 - val_loss: 17.9805 - val_accuracy: 0.2142 - val_precision_4: 0.1553 - val_recall_4: 0.5979 - val_f1_score: 0.2465
# Epoch 2/30
# 47/47 [==============================] - 84s 2s/step - loss: 10.9150 - accuracy: 0.4786 - precision_4: 0.1760 - recall_4: 0.6399 - f1_score: 0.2761 - val_loss: 7.8157 - val_accuracy: 0.1486 - val_precision_4: 0.1486 - val_recall_4: 0.5722 - val_f1_score: 0.2359
# Epoch 3/30
# 28/47 [================>.............] - ETA: 32s - loss: 6.7853 - accuracy: 0.3571 - precision_4: 0.1763 - recall_4: 0.6781 - f1_score: 0.2799
